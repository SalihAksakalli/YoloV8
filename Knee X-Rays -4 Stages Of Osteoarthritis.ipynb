# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 kB 9.3 MB/s eta 0:00:00
# ...

# %%
DATA_DIR = '/content/gdrive/MyDrive/YoloV8/archive (1)/files'

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8l-cls.pt')

results = model.train(data=DATA_DIR, epochs=50, imgsz=64)
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO('/content/runs/classify/train5/weights/last.pt')

result = model('/content/gdrive/MyDrive/YoloV8/archive (1)/files/train/arthritis/3.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/YoloV8/archive (1)/files/train/arthritis/3.jpg: 64x64 arthritis 1.00, stage_2 0.00, stage_4 0.00, fracture 0.00, stage_3 0.00, 81.5ms
# Speed: 0.9ms preprocess, 81.5ms inference, 0.3ms postprocess per image at shape (1, 3, 64, 64)
