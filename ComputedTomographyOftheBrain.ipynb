# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 kB 7.6 MB/s eta 0:00:00
# ...

# %%
DATA_DIR = '/content/gdrive/MyDrive/YoloV8/Computed Tomography (CT) of the Brain/files'

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8l-cls.pt')

results = model.train(data=DATA_DIR, epochs=25, imgsz=64)
# Out:
# ...
# 100%|██████████| 71.7M/71.7M [00:00<00:00, 223MB/s]
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/YoloV8/Computed Tomography (CT) of the Brain/files/train/aneurysm/10.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/YoloV8/Computed Tomography (CT) of the Brain/files/train/aneurysm/10.jpg: 64x64 aneurysm 1.00, cancer 0.00, tumor 0.00, 87.6ms
# Speed: 0.7ms preprocess, 87.6ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)
